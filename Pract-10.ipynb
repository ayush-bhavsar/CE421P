# %% [markdown]
# Create the python model for performing Naïve Bayes on weather CSV to classify the data and interpret the result.

# %%
import pandas  as pd

# %%
df = pd.read_csv("/content/weather (1).csv")
df.head(2)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_9356/135003993.py in <cell line: 0>()
# ----> 1 df = pd.read_csv("/content/weather (1).csv")
#       2 df.head(2)
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df.drop(['WindGustDir','WindDir9am','WindDir3pm'],axis=1)

# %%
df

# %%
df.isnull().sum()

# %%
mean_of_sunshine =  df['Sunshine'].mean()
df['Sunshine'] = df['Sunshine'].fillna(mean_of_sunshine)

mean_of_windgustspeed =  df['WindGustSpeed'].mean()
df['WindGustSpeed'] = df['WindGustSpeed'].fillna(mean_of_windgustspeed)

mean_of_windspeed9am =  df['WindSpeed9am'].mean()
df['WindSpeed9am'] = df['WindSpeed9am'].fillna(mean_of_windspeed9am)

# %%
df.isnull().sum()

# %%
df.head(2)

# %%
df.columns
# df.info()

# %%
df_target = df['RainTomorrow'].value_counts()
import matplotlib.pyplot as plt
plt.bar(df_target.index,df_target.values)

# %%
from sklearn.preprocessing import LabelEncoder
le =LabelEncoder()
df['RainToday'] = le.fit_transform(df['RainToday'])
df['RainTomorrow'] = le.fit_transform(df['RainTomorrow'])
df.head(2)
# df.info()

# %%
x = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
from sklearn.naive_bayes import GaussianNB
gn = GaussianNB()

# %%
df = gn.fit(x_train,y_train)

# %%
y_pred = df.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
score = accuracy_score(y_test,y_pred)
score
