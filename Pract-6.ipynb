# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# create dataset
data = pd.DataFrame({
    "Age": [25, 30, 35, 40, 28, 32, 45, 50],
    "Salary": [30000, 40000, 50000, 60000, 45000, 52000, 65000, 70000],
    "Experience": [1, 3, 5, 7, 2, 4, 8, 10]
})

print("Original Data:\n", data)

# check missing values
print("\nMissing Values:\n", data.isnull().sum())

# fill missing values
data.fillna(data.mean(numeric_only=True), inplace=True)

# normalization using min-max scaler
minmax_scaler = MinMaxScaler()
normalized_data = minmax_scaler.fit_transform(data)
normalized_df = pd.DataFrame(normalized_data, columns=data.columns)

print("\nNormalized Data:\n", normalized_df)

# standardization using standard scaler
standard_scaler = StandardScaler()
standardized_data = standard_scaler.fit_transform(data)
standardized_df = pd.DataFrame(standardized_data, columns=data.columns)

print("\nStandardized Data:\n", standardized_df)

# compare means
print("\nOriginal Mean:\n", data.mean())
print("\nNormalized Mean:\n", normalized_df.mean())
print("\nStandardized Mean:\n", standardized_df.mean())

# save results
normalized_df.to_csv("normalized_data.csv", index=False)
standardized_df.to_csv("standardized_data.csv", index=False)

print("\nProcess Completed")
# Out:
# Original Data:
#     Age  Salary  Experience
# 0   25   30000           1
# 1   30   40000           3
# 2   35   50000           5
# 3   40   60000           7
# 4   28   45000           2
# 5   32   52000           4
# 6   45   65000           8
# 7   50   70000          10
#
# Missing Values:
#  Age           0
# Salary        0
# Experience    0
# dtype: int64
#
# Normalized Data:
#      Age  Salary  Experience
# 0  0.00   0.000    0.000000
# 1  0.20   0.250    0.222222
# 2  0.40   0.500    0.444444
# 3  0.60   0.750    0.666667
# 4  0.12   0.375    0.111111
# 5  0.28   0.550    0.333333
# 6  0.80   0.875    0.777778
# 7  1.00   1.000    1.000000
#
# Standardized Data:
#          Age    Salary  Experience
# 0 -1.305531 -1.729714   -1.371989
# 1 -0.691164 -0.925196   -0.685994
# 2 -0.076796 -0.120678    0.000000
# 3  0.537572  0.683840    0.685994
# 4 -0.936911 -0.522937   -1.028992
# 5 -0.445416  0.040226   -0.342997
# 6  1.151939  1.086099    1.028992
# 7  1.766307  1.488358    1.714986
#
# Original Mean:
#  Age              35.625
# Salary        51500.000
# Experience        5.000
# dtype: float64
#
# Normalized Mean:
#  Age           0.425000
# Salary        0.537500
# Experience    0.444444
# dtype: float64
#
# Standardized Mean:
#  Age           0.000000e+00
# Salary       -5.551115e-17
# Experience    0.000000e+00
# dtype: float64
#
# Process Completed
